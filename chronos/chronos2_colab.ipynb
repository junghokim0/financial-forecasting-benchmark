# %% [markdown]
# # Chronos-2 LoRA Fine-tuned — Cryptova Benchmark
# GPU runtime을 선택하고, Google Drive에 benchmark 폴더 전체를 올린 뒤 실행합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
BENCHMARK_ROOT = '/content/drive/MyDrive/crypto/benchmark'
# !nvidia-smi
# !pip install -q -r "{BENCHMARK_ROOT}/chronos/requirements-colab.txt"

# %% [markdown]
# ## 데이터 검증 — 모델 다운로드 및 학습 없음

# %%
# !python "{BENCHMARK_ROOT}/chronos/validate_chronos2_data.py" --benchmark-root "{BENCHMARK_ROOT}"

# %% [markdown]
# ## Chart-only Rolling 1~3 LoRA Fine-tuning

# %%
# !python "{BENCHMARK_ROOT}/chronos/train_chronos2_lora.py" --benchmark-root "{BENCHMARK_ROOT}" --rolling 1 2 3 --execute-training

# %%
# !python "{BENCHMARK_ROOT}/chronos/aggregate_chronos2_results.py" --benchmark-root "{BENCHMARK_ROOT}"
